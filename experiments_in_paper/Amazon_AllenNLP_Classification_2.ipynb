# %%
import json
import os
from IPython.display import Image
import numpy as np
import pandas as pd

# %load_ext autoreload
# %autoreload 2

# %%
def load_json(path):
    with open(path) as f:
        data = [json.loads(line) for line in f]
    return data

def load_json_file(path):
    with open(path, 'r', encoding='utf8') as f:
        return json.load(f)

def create_dir(dir_path):
    if not os.path.exists(dir_path):
        os.makedirs(dir_path)

# %%
#%cd '/content/drive/MyDrive/AdaptOrDie/dont-stop-pretraining-modified'
# %cd 'dont-stop-pretraining-modified'
# Out:
# /home/jupyter/dental-notebooks/ltuzova/gatech_dl/final/AdaptOrDie/dont-stop-pretraining-modified

# %%
#Path to virtual environment on my work server. Don't need it if run under colab
venv_path = "/home/jupyter/dental-notebooks/ltuzova/.ltuzova_env/bin"  # Adjust this path as necessary
os.environ["PATH"] = venv_path + os.pathsep + os.environ["PATH"]

# %% [markdown]
# ## Run Amazon Classification on 25M DAPT pretrained model

# %%
# !python -m scripts.train \
        --config training_config/classifier.jsonnet \
        --serialization_dir model_logs/amazon_dapt_25_2 \
        --hyperparameters ROBERTA_CLASSIFIER_SMALL \
        --dataset amazon \
        --model $(pwd)/pretrained_models/amazon_helpfulness_classification_on_25M_full_pretrained \
        --device 4 \
        --perf +f1 \
        --evaluate_on_test
# Out:
# /home/jupyter/dental-notebooks/ltuzova/.ltuzova_env/lib/python3.7/site-packages/torchvision/io/image.py:13: UserWarning: Failed to load image Python extension: /home/jupyter/dental-notebooks/ltuzova/.ltuzova_env/lib/python3.7/site-packages/torchvision/image.so: undefined symbol: _ZN2at4_ops19empty_memory_format4callEN3c108ArrayRefIlEENS2_8optionalINS2_10ScalarTypeEEENS5_INS2_6LayoutEEENS5_INS2_6DeviceEEENS5_IbEENS5_INS2_12MemoryFormatEEE
#   warn(f"Failed to load image Python extension: {e}")
# 2024-04-22 23:14:55,366 - INFO - allennlp.common.params - evaluation = None
# 2024-04-22 23:14:55,366 - INFO - allennlp.common.params - include_in_archive = None
# 2024-04-22 23:14:55,367 - INFO - allennlp.common.params - random_seed = 698041
# 2024-04-22 23:14:55,367 - INFO - allennlp.common.params - numpy_seed = 698041
# 2024-04-22 23:14:55,367 - INFO - allennlp.common.params - pytorch_seed = 698041
# 2024-04-22 23:14:55,368 - INFO - allennlp.common.checks - Pytorch version: 1.13.1+cu117
# ...

# %%
m = [{
    'exp':'dapt_25_2',
    "best_epoch": 4,
  "peak_worker_0_memory_MB": 11393.5625,
  "peak_gpu_0_memory_MB": 0,
  "training_duration": "4:45:20.485988",
  "epoch": 7,
  "training_f1": 0.9486473798751831,
  "training_accuracy": 0.9747941449531892,
  "training_loss": 0.0789916685709072,
  "training_worker_0_memory_MB": 11393.5625,
  "training_gpu_0_memory_MB": 0.0,
  "validation_f1": 0.6782072484493256,
  "validation_accuracy": 0.8688,
  "validation_loss": 0.5802993129644269,
  "best_validation_f1": 0.682471364736557,
  "best_validation_accuracy": 0.8628,
  "best_validation_loss": 0.44021145253332133,
  "test_f1": 0.6933344751596451,
  "test_accuracy": 0.86816,
  "test_loss": 0.421720123664498
}]

# %%
metrics = pd.DataFrame(m)

# %%
metrics
# Out:
#          exp  best_epoch  peak_worker_0_memory_MB  peak_gpu_0_memory_MB  \
# 0  dapt_25_2           4               11393.5625                     0
#
#   training_duration  epoch  training_f1  training_accuracy  training_loss  \
# 0    4:45:20.485988      7     0.948647           0.974794       0.078992
#
#    training_worker_0_memory_MB  training_gpu_0_memory_MB  validation_f1  \
# 0                   11393.5625                       0.0       0.678207
#
#    validation_accuracy  validation_loss  best_validation_f1  \
# 0               0.8688         0.580299            0.682471
#
#    best_validation_accuracy  best_validation_loss   test_f1  test_accuracy  \
# 0                    0.8628              0.440211  0.693334        0.86816
#
#    test_loss
# 0    0.42172

# %% [markdown]
# ## Run Amazon Classification on 5M DAPT pretrained model

# %%
# !python -m scripts.train \
        --config training_config/classifier.jsonnet \
        --serialization_dir model_logs/amazon_dapt_5_2 \
        --hyperparameters ROBERTA_CLASSIFIER_SMALL \
        --dataset amazon \
        --model $(pwd)/pretrained_models/amazon_helpfulness_classification_on_5M_full_pretrained \
        --device 4 \
        --perf +f1 \
        --evaluate_on_test
# Out:
# /home/jupyter/dental-notebooks/ltuzova/.ltuzova_env/lib/python3.7/site-packages/torchvision/io/image.py:13: UserWarning: Failed to load image Python extension: /home/jupyter/dental-notebooks/ltuzova/.ltuzova_env/lib/python3.7/site-packages/torchvision/image.so: undefined symbol: _ZN2at4_ops19empty_memory_format4callEN3c108ArrayRefIlEENS2_8optionalINS2_10ScalarTypeEEENS5_INS2_6LayoutEEENS5_INS2_6DeviceEEENS5_IbEENS5_INS2_12MemoryFormatEEE
#   warn(f"Failed to load image Python extension: {e}")
# 2024-04-23 07:57:35,386 - INFO - allennlp.common.params - evaluation = None
# 2024-04-23 07:57:35,386 - INFO - allennlp.common.params - include_in_archive = None
# 2024-04-23 07:57:35,387 - INFO - allennlp.common.params - random_seed = 316196
# 2024-04-23 07:57:35,387 - INFO - allennlp.common.params - numpy_seed = 316196
# 2024-04-23 07:57:35,387 - INFO - allennlp.common.params - pytorch_seed = 316196
# 2024-04-23 07:57:35,388 - INFO - allennlp.common.checks - Pytorch version: 1.13.1+cu117
# ...

# %%
m = [{
    'exp':'dapt_5_2',
    "best_epoch": 5,
  "peak_worker_0_memory_MB": 11387.5703125,
  "peak_gpu_0_memory_MB": 0,
  "training_duration": "5:19:49.695089",
  "epoch": 8,
  "training_f1": 0.9600622653961182,
  "training_accuracy": 0.9802691516776427,
  "training_loss": 0.060555126853101056,
  "training_worker_0_memory_MB": 11387.5703125,
  "training_gpu_0_memory_MB": 0.0,
  "validation_f1": 0.6764602214097977,
  "validation_accuracy": 0.8662,
  "validation_loss": 0.5576216892098276,
  "best_validation_f1": 0.6956218481063843,
  "best_validation_accuracy": 0.8672,
  "best_validation_loss": 0.5764561994774892,
  "test_f1": 0.690709725022316,
  "test_accuracy": 0.87092,
  "test_loss": 0.5570978858697055
}]

# %%
metrics = pd.DataFrame(m)

# %%
metrics
# Out:
#         exp  best_epoch  peak_worker_0_memory_MB  peak_gpu_0_memory_MB  \
# 0  dapt_5_2           5             11387.570312                     0
#
#   training_duration  epoch  training_f1  training_accuracy  training_loss  \
# 0    5:19:49.695089      8     0.960062           0.980269       0.060555
#
#    training_worker_0_memory_MB  training_gpu_0_memory_MB  validation_f1  \
# 0                 11387.570312                       0.0        0.67646
#
#    validation_accuracy  validation_loss  best_validation_f1  \
# 0               0.8662         0.557622            0.695622
#
#    best_validation_accuracy  best_validation_loss  test_f1  test_accuracy  \
# 0                    0.8672              0.576456  0.69071        0.87092
#
#    test_loss
# 0   0.557098

# %% [markdown]
# ## Run Amazon Classification on TAPT pretrained model

# %%
# !python -m scripts.train \
        --config training_config/classifier.jsonnet \
        --serialization_dir model_logs/amazon_tapt_2 \
        --hyperparameters ROBERTA_CLASSIFIER_SMALL \
        --dataset amazon \
        --model $(pwd)/pretrained_models/amazon_helpfulness_classification_on_tapt_full_pretrained \
        --device 4 \
        --perf +f1 \
        --evaluate_on_test
# Out:
# /home/jupyter/dental-notebooks/ltuzova/.ltuzova_env/lib/python3.7/site-packages/torchvision/io/image.py:13: UserWarning: Failed to load image Python extension: /home/jupyter/dental-notebooks/ltuzova/.ltuzova_env/lib/python3.7/site-packages/torchvision/image.so: undefined symbol: _ZN2at4_ops19empty_memory_format4callEN3c108ArrayRefIlEENS2_8optionalINS2_10ScalarTypeEEENS5_INS2_6LayoutEEENS5_INS2_6DeviceEEENS5_IbEENS5_INS2_12MemoryFormatEEE
#   warn(f"Failed to load image Python extension: {e}")
# 2024-04-23 04:17:09,769 - INFO - allennlp.common.params - evaluation = None
# 2024-04-23 04:17:09,769 - INFO - allennlp.common.params - include_in_archive = None
# 2024-04-23 04:17:09,769 - INFO - allennlp.common.params - random_seed = 674360
# 2024-04-23 04:17:09,769 - INFO - allennlp.common.params - numpy_seed = 674360
# 2024-04-23 04:17:09,770 - INFO - allennlp.common.params - pytorch_seed = 674360
# 2024-04-23 04:17:09,770 - INFO - allennlp.common.checks - Pytorch version: 1.13.1+cu117
# ...

# %%
m = [{
    'exp':'tapt_2',
    "best_epoch": 2,
  "peak_worker_0_memory_MB": 11393.890625,
  "peak_gpu_0_memory_MB": 0,
  "training_duration": "3:33:50.662138",
  "epoch": 5,
  "training_f1": 0.9243098497390747,
  "training_accuracy": 0.9632627916460594,
  "training_loss": 0.10621187017026587,
  "training_worker_0_memory_MB": 11393.890625,
  "training_gpu_0_memory_MB": 0.0,
  "validation_f1": 0.6893974393606186,
  "validation_accuracy": 0.8706,
  "validation_loss": 0.4648715320851106,
  "best_validation_f1": 0.6971052438020706,
  "best_validation_accuracy": 0.878,
  "best_validation_loss": 0.3060052808874046,
  "test_f1": 0.6882117390632629,
  "test_accuracy": 0.87668,
  "test_loss": 0.3059441505199011
}]

# %%
metrics = pd.DataFrame(m)

# %%
metrics
# Out:
#       exp  best_epoch  peak_worker_0_memory_MB  peak_gpu_0_memory_MB  \
# 0  tapt_2           2             11393.890625                     0
#
#   training_duration  epoch  training_f1  training_accuracy  training_loss  \
# 0    3:33:50.662138      5      0.92431           0.963263       0.106212
#
#    training_worker_0_memory_MB  training_gpu_0_memory_MB  validation_f1  \
# 0                 11393.890625                       0.0       0.689397
#
#    validation_accuracy  validation_loss  best_validation_f1  \
# 0               0.8706         0.464872            0.697105
#
#    best_validation_accuracy  best_validation_loss   test_f1  test_accuracy  \
# 0                     0.878              0.306005  0.688212        0.87668
#
#    test_loss
# 0   0.305944

# %% [markdown]
# ## Run Amazon Classification on DAPT/TAPT

# %%
# !python -m scripts.train \
        --config training_config/classifier.jsonnet \
        --serialization_dir model_logs/amazon_dapt_tapt_2 \
        --hyperparameters ROBERTA_CLASSIFIER_SMALL \
        --dataset amazon \
        --model $(pwd)/pretrained_models/amazon_helpfulness_classification_on_25M_full_pretrained \
        --device 4 \
        --perf +f1 \
        --evaluate_on_test
# Out:
# /home/jupyter/dental-notebooks/ltuzova/.ltuzova_env/lib/python3.7/site-packages/torchvision/io/image.py:13: UserWarning: Failed to load image Python extension: /home/jupyter/dental-notebooks/ltuzova/.ltuzova_env/lib/python3.7/site-packages/torchvision/image.so: undefined symbol: _ZN2at4_ops19empty_memory_format4callEN3c108ArrayRefIlEENS2_8optionalINS2_10ScalarTypeEEENS5_INS2_6LayoutEEENS5_INS2_6DeviceEEENS5_IbEENS5_INS2_12MemoryFormatEEE
#   warn(f"Failed to load image Python extension: {e}")
# 2024-04-23 16:25:12,468 - INFO - allennlp.common.params - evaluation = None
# 2024-04-23 16:25:12,469 - INFO - allennlp.common.params - include_in_archive = None
# 2024-04-23 16:25:12,469 - INFO - allennlp.common.params - random_seed = 950948
# 2024-04-23 16:25:12,469 - INFO - allennlp.common.params - numpy_seed = 950948
# 2024-04-23 16:25:12,469 - INFO - allennlp.common.params - pytorch_seed = 950948
# 2024-04-23 16:25:12,470 - INFO - allennlp.common.checks - Pytorch version: 1.13.1+cu117
# ...

# %%
m_json = load_json_file("model_logs/amazon_dapt_tapt_2/metrics.json")
m_json['exp']='dapt_tapt_2'

metrics = pd.DataFrame([m_json])

metrics
# Out:
#    best_epoch  peak_worker_0_memory_MB  peak_gpu_0_memory_MB  \
# 0           0             11399.585938                     0
#
#   training_duration  epoch  training_f1  training_accuracy  training_loss  \
# 0    2:22:35.343601      3     0.877881           0.942387       0.160051
#
#    training_worker_0_memory_MB  training_gpu_0_memory_MB  validation_f1  \
# 0                 11399.585938                       0.0       0.663187
#
#    validation_accuracy  validation_loss  best_validation_f1  \
# 0                 0.87          0.45237            0.712019
#
#    best_validation_accuracy  best_validation_loss   test_f1  test_accuracy  \
# 0                    0.8704              0.314731  0.707645        0.87292
#
#    test_loss          exp
# 0   0.308033  dapt_tapt_2

# %% [markdown]
# ## Run Amazon Classification on TAPT, 100 epohcs, test as train

# %%
# !python -m scripts.train \
        --config training_config/classifier.jsonnet \
        --serialization_dir model_logs/amazon_tapt_test_2 \
        --hyperparameters ROBERTA_CLASSIFIER_SMALL \
        --dataset amazon \
        --model $(pwd)/pretrained_models/amazon_helpfulness_classification_on_tapt_test_as_train \
        --device 4 \
        --perf +f1 \
        --evaluate_on_test
# Out:
# /home/jupyter/dental-notebooks/ltuzova/.ltuzova_env/lib/python3.7/site-packages/torchvision/io/image.py:13: UserWarning: Failed to load image Python extension: /home/jupyter/dental-notebooks/ltuzova/.ltuzova_env/lib/python3.7/site-packages/torchvision/image.so: undefined symbol: _ZN2at4_ops19empty_memory_format4callEN3c108ArrayRefIlEENS2_8optionalINS2_10ScalarTypeEEENS5_INS2_6LayoutEEENS5_INS2_6DeviceEEENS5_IbEENS5_INS2_12MemoryFormatEEE
#   warn(f"Failed to load image Python extension: {e}")
# 2024-04-23 21:08:47,481 - INFO - allennlp.common.params - evaluation = None
# 2024-04-23 21:08:47,481 - INFO - allennlp.common.params - include_in_archive = None
# 2024-04-23 21:08:47,482 - INFO - allennlp.common.params - random_seed = 910363
# 2024-04-23 21:08:47,482 - INFO - allennlp.common.params - numpy_seed = 910363
# 2024-04-23 21:08:47,482 - INFO - allennlp.common.params - pytorch_seed = 910363
# 2024-04-23 21:08:47,483 - INFO - allennlp.common.checks - Pytorch version: 1.13.1+cu117
# ...

# %%
m_json = load_json_file("model_logs/amazon_tapt_test_2/metrics.json")
m_json['exp']='tapt_test_2'

metrics = pd.DataFrame([m_json])

metrics
# Out:
#    best_epoch  peak_worker_0_memory_MB  peak_gpu_0_memory_MB  \
# 0           5             11392.257812                     0
#
#   training_duration  epoch  training_f1  training_accuracy  training_loss  \
# 0    5:22:10.187579      8     0.949584           0.975089       0.076423
#
#    training_worker_0_memory_MB  training_gpu_0_memory_MB  validation_f1  \
# 0                 11392.257812                       0.0       0.667643
#
#    validation_accuracy  validation_loss  best_validation_f1  \
# 0               0.8684         0.558725            0.699329
#
#    best_validation_accuracy  best_validation_loss   test_f1  test_accuracy  \
# 0                    0.8646              0.420074  0.692497        0.86604
#
#    test_loss          exp
# 0   0.401281  tapt_test_2

# %% [markdown]
# # Roberta Base Big

# %%
# !python -m scripts.train \
        --config training_config/classifier.jsonnet \
        --serialization_dir model_logs/amazon_roberta_base_big_3 \
        --hyperparameters ROBERTA_CLASSIFIER_BIG \
        --dataset amazon \
        --model roberta-base \
        --device 4 \
        --perf +f1 \
        --evaluate_on_test
# Out:
# /home/jupyter/dental-notebooks/ltuzova/.ltuzova_env/lib/python3.7/site-packages/torchvision/io/image.py:13: UserWarning: Failed to load image Python extension: /home/jupyter/dental-notebooks/ltuzova/.ltuzova_env/lib/python3.7/site-packages/torchvision/image.so: undefined symbol: _ZN2at4_ops19empty_memory_format4callEN3c108ArrayRefIlEENS2_8optionalINS2_10ScalarTypeEEENS5_INS2_6LayoutEEENS5_INS2_6DeviceEEENS5_IbEENS5_INS2_12MemoryFormatEEE
#   warn(f"Failed to load image Python extension: {e}")
# 2024-04-24 20:30:15,828 - INFO - allennlp.common.params - evaluation = None
# 2024-04-24 20:30:15,828 - INFO - allennlp.common.params - include_in_archive = None
# 2024-04-24 20:30:15,828 - INFO - allennlp.common.params - random_seed = 341439
# 2024-04-24 20:30:15,829 - INFO - allennlp.common.params - numpy_seed = 341439
# 2024-04-24 20:30:15,829 - INFO - allennlp.common.params - pytorch_seed = 341439
# 2024-04-24 20:30:15,829 - INFO - allennlp.common.checks - Pytorch version: 1.13.1+cu117
# ...

# %% [markdown]
# # Roberta Base Big

# %%
# !python -m scripts.train \
        --config training_config/classifier.jsonnet \
        --serialization_dir model_logs/amazon_roberta_base_big_4 \
        --hyperparameters ROBERTA_CLASSIFIER_BIG \
        --dataset amazon \
        --model roberta-base \
        --device 4 \
        --perf +f1 \
        --evaluate_on_test
# Out:
# /home/jupyter/dental-notebooks/ltuzova/.ltuzova_env/lib/python3.7/site-packages/torchvision/io/image.py:13: UserWarning: Failed to load image Python extension: /home/jupyter/dental-notebooks/ltuzova/.ltuzova_env/lib/python3.7/site-packages/torchvision/image.so: undefined symbol: _ZN2at4_ops19empty_memory_format4callEN3c108ArrayRefIlEENS2_8optionalINS2_10ScalarTypeEEENS5_INS2_6LayoutEEENS5_INS2_6DeviceEEENS5_IbEENS5_INS2_12MemoryFormatEEE
#   warn(f"Failed to load image Python extension: {e}")
# 2024-04-24 23:22:19,659 - INFO - allennlp.common.params - evaluation = None
# 2024-04-24 23:22:19,660 - INFO - allennlp.common.params - include_in_archive = None
# 2024-04-24 23:22:19,660 - INFO - allennlp.common.params - random_seed = 165386
# 2024-04-24 23:22:19,660 - INFO - allennlp.common.params - numpy_seed = 165386
# 2024-04-24 23:22:19,660 - INFO - allennlp.common.params - pytorch_seed = 165386
# 2024-04-24 23:22:19,661 - INFO - allennlp.common.checks - Pytorch version: 1.13.1+cu117
# ...

# %%
m_json = load_json_file("model_logs/amazon_roberta_base_big_4/metrics.json")
m_json['exp']='roberta_base_big_4'

metrics = pd.DataFrame([m_json])

metrics
# Out:
#    best_epoch  peak_worker_0_memory_MB  peak_gpu_0_memory_MB  \
# 0           0             11394.429688                     0
#
#   training_duration  epoch  training_f1  training_accuracy  training_loss  \
# 0    1:46:59.253343      2     0.746312           0.893138       0.261785
#
#    training_worker_0_memory_MB  training_gpu_0_memory_MB  validation_f1  \
# 0                 11394.429688                       0.0       0.658993
#
#    validation_accuracy  validation_loss  best_validation_f1  \
# 0               0.8716         0.324407             0.66677
#
#    best_validation_accuracy  best_validation_loss   test_f1  test_accuracy  \
# 0                    0.8664              0.317532  0.670358        0.86968
#
#    test_loss                 exp
# 0   0.313972  roberta_base_big_4
