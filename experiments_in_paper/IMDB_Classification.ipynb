# %% [markdown]
# <a href="https://colab.research.google.com/github/BigTMiami/AdaptOrDie/blob/main/Amazon_Helpfulness_Classification_Full_Dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
os.environ['CUDA_LAUNCH_BLOCKING'] = "1"
from google.colab import drive
from google.colab import runtime
drive.mount('/content/drive')
# %cd '/content/drive/MyDrive/AdaptOrDie/'
# %load_ext autoreload
# %autoreload 2
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive/AdaptOrDie

# %%
# !pip install transformers[torch] datasets huggingface_hub scikit-learn
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 510.5/510.5 kB 14.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 297.4/297.4 kB 30.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 15.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 25.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 17.5 MB/s eta 0:00:00
# ...
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# ...
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# ...
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# ...
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# ...
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# ...
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# ...

# %%
import classification_training

# %% [markdown]
# # IMDB Task

# %% [markdown]
# ## Training on Roberta

# %%
trainer = classification_training.run_classifier(
    output_dir = 'imdb_classification_roberta_best_epoch_f1',
    pretrained_model='roberta-base',
    classification_task = 'imdb',
    torch_compile=True,
    train = True,
    evaluate_on_test = True)
trainer.push_to_hub('imdb_classification_on_roberta_best_epoch_f1')

# print("Disconnecting Session")
# runtime.unassign()
# Out:
# Early stopping with best val on f1 macro
# Classification task: imdb, pretrained model: roberta-base
# Dataset: DatasetDict({
#     train: Dataset({
#         features: ['label', 'input_ids', 'attention_mask'],
#         num_rows: 20000
#     })
#     test: Dataset({
#         features: ['label', 'input_ids', 'attention_mask'],
#         num_rows: 25000
#     })
#     dev: Dataset({
#         features: ['label', 'input_ids', 'attention_mask'],
#         num_rows: 5000
#     })
# })
# Some weights of RobertaForSequenceClassification were not initialized from the model checkpoint at roberta-base and are newly initialized: ['classifier.dense.bias', 'classifier.dense.weight', 'classifier.out_proj.bias', 'classifier.out_proj.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Classification config: RobertaConfig {
#   "_name_or_path": "roberta-base",
#   "architectures": [
#     "RobertaForMaskedLM"
#   ],
# ...

# %%
from datasets import load_dataset
dataset = load_dataset("BigTMiami/imdb_sentiment_dataset")

# %%
trainer.evaluate(dataset["dev"])
# Out:
#     <div>
#
#       <progress value='1876' max='1563' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [1563/1563 10:01]
#     </div>
# {'eval_loss': 0.2286449521780014,
#  'eval_accuracy': 0.9506,
#  'eval_f1_macro': 0.9505999822159936,
#  'eval_runtime': 50.5174,
#  'eval_samples_per_second': 98.976,
#  'eval_steps_per_second': 6.196,
#  'epoch': 3.0}

# %%
trainer.evaluate(dataset["test"])
# Out:
#     <div>
#
#       <progress value='3439' max='1563' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [1563/1563 14:32]
#     </div>
# {'eval_loss': 0.22106385231018066,
#  'eval_accuracy': 0.95312,
#  'eval_f1_macro': 0.9531185715041213,
#  'eval_runtime': 249.4307,
#  'eval_samples_per_second': 100.228,
#  'eval_steps_per_second': 6.266,
#  'epoch': 3.0}

# %% [markdown]
# ## Training on 5M pre-trained model

# %%
trainer = classification_training.run_classifier(
    output_dir = 'imdb_classification_on_5M_full_pretrained_best_epoch_f1',
    pretrained_model='BigTMiami/amazon_pretraining_5M_model_corrected',
    classification_task = 'imdb',
    torch_compile=True,
    train = True,
    evaluate_on_test = True)

trainer.push_to_hub('imdb_classification_on_5M_full_pretrained_best_epoch_f1')

# print("Disconnecting Session")
# runtime.unassign()
# Out:
# Early stopping with best val on f1 macro
# Classification task: imdb, pretrained model: BigTMiami/amazon_pretraining_5M_model_corrected
# Dataset: DatasetDict({
#     train: Dataset({
#         features: ['label', 'input_ids', 'attention_mask'],
#         num_rows: 20000
#     })
#     test: Dataset({
#         features: ['label', 'input_ids', 'attention_mask'],
#         num_rows: 25000
#     })
#     dev: Dataset({
#         features: ['label', 'input_ids', 'attention_mask'],
#         num_rows: 5000
#     })
# })
# Classification config: RobertaConfig {
#   "_name_or_path": "roberta-base",
#   "architectures": [
#     "RobertaForMaskedLM"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "bos_token_id": 0,
#   "classifier_dropout": 0.1,
#   "eos_token_id": 2,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "id2label": {
#     "0": 0,
#     "1": 1
#   },
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "label2id": {
# ...

# %% [markdown]
# ## Training on 25M pre-trained model

# %%
trainer = classification_training.run_classifier(
    output_dir = 'imdb_classification_on_25M_full_pretrained_best_epoch_f1',
    pretrained_model='ltuzova/amazon_domain_pretrained_model',
    classification_task = 'imdb',
    torch_compile=True,
    train = True,
    evaluate_on_test = True
)
trainer.push_to_hub('imdb_classification_on_25M_full_pretrained_best_epoch_f1')

print("Disconnecting Session")
runtime.unassign()
# Out:
# Early stopping with best val on f1 macro
# Classification task: imdb, pretrained model: ltuzova/amazon_domain_pretrained_model
# Dataset: DatasetDict({
#     train: Dataset({
#         features: ['label', 'input_ids', 'attention_mask'],
#         num_rows: 20000
#     })
#     test: Dataset({
#         features: ['label', 'input_ids', 'attention_mask'],
#         num_rows: 25000
#     })
#     dev: Dataset({
#         features: ['label', 'input_ids', 'attention_mask'],
#         num_rows: 5000
#     })
# })
# Classification config: RobertaConfig {
#   "_name_or_path": "roberta-base",
#   "architectures": [
#     "RobertaForMaskedLM"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "bos_token_id": 0,
#   "classifier_dropout": 0.1,
#   "eos_token_id": 2,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "id2label": {
#     "0": 0,
#     "1": 1
#   },
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "label2id": {
#     "0": 0,
# ...
