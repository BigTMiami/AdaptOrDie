# %% [markdown]
# <a href="https://colab.research.google.com/github/BigTMiami/AdaptOrDie/blob/main/Condalab_Allennlp_Setup_Failed.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# This mounts into your google drive space.  You need to allow for access and create the folder to mount to.

# %%
# !pip install -q condacolab
import condacolab
condacolab.install()
# Out:
# ⏬ Downloading https://github.com/conda-forge/miniforge/releases/download/23.11.0-0/Mambaforge-23.11.0-0-Linux-x86_64.sh...
# 📦 Installing...
# 📌 Adjusting configuration...
# 🩹 Patching environment...
# ⏲ Done in 0:00:12
# 🔁 Restarting kernel...

# %%
import condacolab
condacolab.check()
# Out:
# ✨🍰✨ Everything looks OK!

# %%
# !conda install -c conda-forge python=3.8
# Out:
# Channels:
#  - conda-forge
# Platform: linux-64
# done
# failed
#
# SpecsConfigurationConflictError: Requested specs conflict with configured specs.
#   requested specs:
#     - python=3.8
#   pinned specs:
#     - cuda-version=12
#     - python=3.10
#     - python_abi=3.10[build=*cp310*]
# Use 'conda config --show-sources' to look for 'pinned_specs' and 'track_features'
# configuration parameters.  Pinned specs may also be defined in the file
# /usr/local/conda-meta/pinned.

# %%
# !python --version

# %%
# !conda install  allennlp
# Out:
# Channels:
#  - conda-forge
# Platform: linux-64
# done
# / warning  libmamba Added empty dependency for problem type SOLVER_RULE_UPDATE
# failed
#
# LibMambaUnsatisfiableError: Encountered problems while solving:
#   - nothing provides pytorch >=0.4.1,<0.5.0 needed by allennlp-0.7.2-py36h470a237_0
#
# Could not solve for environment specs
# The following packages are incompatible
# ├─ allennlp is installable with the potential options
# │  ├─ allennlp 0.7.2 would require
# │  │  └─ pytorch >=0.4.1,<0.5.0 , which does not exist (perhaps a missing channel);
# │  ├─ allennlp [1.3.0|1.4.0|...|2.5.0] would require
# │  │  └─ python >=3.6,<3.7.0a0 , which can be installed;
# │  ├─ allennlp [1.3.0|1.4.0|...|2.9.3] would require
# │  │  └─ python >=3.7,<3.8.0a0 , which can be installed;
# │  ├─ allennlp [1.3.0|1.4.0|...|2.9.3] would require
# │  │  └─ python >=3.8,<3.9.0a0 , which can be installed;
# │  └─ allennlp [1.3.0|2.10.0|...|2.9.3] would require
# ...
